# %%
import lief
import os
import re
from pprint import pprint

from helpers import *

# %%
binary_file = lief.PE.parse(r"D:\hackSF\filtered_dataset\Win32_EXE\186")
#print(binary_file)


Parsed_Binary_File = Parse_Lief_Binary_to_Dict(binary_file)
pprint(Parsed_Binary_File)
# Out:
# {'            publicKeyToken="6595b64144ccf1df"\r': {},
#  '        <requestedPrivileges>\r': {},
#  '        <supportedOS Id="{4a2f28e3-53b9-4441-ba9c-d69d4a4a6e38}"/>\r': {},
#  '    <windowsSettings>\r': {},
#  '    version="1.0.0.0"\r': {},
#  '</dependency>\r': {},
#  'Data directories': {'RVA': ' 0x   0',
#                       'Section': '  .rdata',
#                       'Size': ' 0x  0'},
#  'Dos Header': {'Address Of New Exe Header': '    100',
#                 'Address Of Relocation Table': '  40',
#                 'Checksum': '                     0',
#                 'File Size In Pages': '           2',
#                 'Header Size In Paragraphs': '    4',
#                 'Initial IP': '                   0',
#                 'Initial Relative CS': '          0',
#                 'Initial Relative SS': '          0',
#                 'Initial SP': '                   b8',
#                 'Magic': '                        5a4d',
# ...

# %%
#for field in DOS_Header_Fields:
#    FieldData = re.findall(field, binary_file)

# %%
#import os
#print(hex(os.path.getsize(r"D:\hackSF\filtered_dataset\Win32_EXE\186")))

# %%
'''
# Just a library I found on the internet that extracts some useful features from PE files
# but this library fucking sucks :P
# I will just write my own code instead of trying to make an external library run

import ember

import numpy as np
import pandas as pd
path_To_Dataset = r"D:\hackSF\filtered_dataset\Win32_EXE"#.replace("\\", '/')

ember.create_vectorized_features(path_To_Dataset)
ember.create_metadata(path_To_Dataset)
'''
